# %% [markdown]
# # Imports

# %%
from FraudDetector import Bank_Account_Fraud_Detection

# %% [markdown]
# # Reading Dataset

# %%
# Load Base.csv
fraud_detector = Bank_Account_Fraud_Detection('data/')
dataset = fraud_detector.load_data('Base')

# %% [markdown]
# # Train-Test-Split

# %%
fraud_detector.train_test_split()
# Out:
# /tmp/ipykernel_1656/1189479294.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.drop('month', axis=1, inplace=True)
# /tmp/ipykernel_1656/1189479294.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.drop('month', axis=1, inplace=True)

# %% [markdown]
# # Applying One-hot-encoding

# %%
fraud_detector.one_hot_encoder()
# Out:
#        payment_type employment_status housing_status    source  device_os
# 0                AA                CA             BA  INTERNET    windows
# 1                AB                CA             BA  INTERNET    windows
# 2                AC                CB             BA  INTERNET      other
# 3                AB                CA             BA  INTERNET      linux
# 4                AB                CA             BA  INTERNET  macintosh
# ...             ...               ...            ...       ...        ...
# 999995           AB                CA             BC  INTERNET      linux
# 999996           AC                CC             BC  INTERNET    windows
# 999997           AA                CF             BC  INTERNET      other
# 999998           AA                CA             BA  INTERNET    windows
# 999999           AA                CA             BE  INTERNET      linux
#
# [1000000 rows x 5 columns]

# %% [markdown]
# # Model Creation

# %%
fraud_detector.fit_baseline()
# Out:
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# AUC: 0.7418143731983731
# TPR:  26.44%
# FPR:  5.0%
# Threshold:  0.79
# Predictive Equality:  99.95%

# %%
fraud_detector.fit_baseline('XGB')
# Out:
# AUC: 0.8668148463488872
# TPR:  47.599999999999994%
# FPR:  4.99%
# Threshold:  0.71
# Predictive Equality:  73.96000000000001%

# %%
fraud_detector.fit_baseline('RF')
# Out:
# AUC: 0.8044989751705979
# TPR:  35.02%
# FPR:  3.4299999999999997%
# Threshold:  0.05
# Predictive Equality:  34.94%

# %%
fraud_detector.fit_baseline('DNN')
# Out:
# 6407/6407 [==============================] - 10s 1ms/step
# AUC: 0.8872665130277185
# TPR:  52.68000000000001%
# FPR:  5.0%
# Threshold:  0.9
# Predictive Equality:  87.41%
